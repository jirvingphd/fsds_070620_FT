# %% [markdown]
# # Sect 06:  Visualizations

# %% [markdown]
# - onl01-dtsc-pt-041320
# - 05/06/20

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# - Matplotlib is the backbone of plotting in python and used by pandas,seaborn,etc.
#     - [Matplotlib Example Gallery](https://matplotlib.org/gallery/index.html#examples-index)
#     - [Seaborn Example Gallery](https://seaborn.pydata.org/examples/index.html)
#     - ['Pandas Visualization docs']('https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html')
#
# -  *Matplotlib is powerful but can be a bit confusing at times because of its 2 sets of commands:*
#     - the matplotlib.pyplot functions (`plt.bar()`,`plt.title()`)
#     - the object_oriented methods (`ax.bar()`,`ax.set_title()`)
#
# - The 2 syntaxes can be confusing at first and cause problems & odd results when mixed together.
#     - Learn about some of the problems when mixing types.
#     - Example: see how plt.title()/plt.xlabel(),etc. can behave strangely in subplots.
#
#     - **Bookmark this article, its the best explanation of how matploblib'S 2 interfaces work:**
# > ["Artist" in Matplotlib - something I wanted to know before spending tremendous hours on googling how-tos.](https://dev.to/skotaro/artist-in-matplotlib---something-i-wanted-to-know-before-spending-tremendous-hours-on-googling-how-tos--31oo)<br>
#
#
#
# - Seaborn and Pandas plots can be updated with matplotlib commands's OOP type of commands (`ax.set_title()`)

# %% [markdown]
# ## Questions/Comments?

# %% [markdown]
# ### From the Gdoc

# %% [markdown]
# ___

# %% [markdown]
# # Intro to Matplotlib

# %% [markdown]
# ##  Matplotlib Refs

# %% [markdown]
# - Matplotlib is the backbone of plotting in python and used by pandas,seaborn,etc.
#     - [Matplotlib Example Gallery](https://matplotlib.org/gallery/index.html#examples-index)
#     - [Seaborn Example Gallery](https://seaborn.pydata.org/examples/index.html)
#     - ['Pandas Visualization docs']('https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html')
#
#
#
# -  *Matplotlib is powerful but can be a bit confusing at times because of its 2 sets of commands:*
#     - the matplotlib.pyplot functions (`plt.bar()`,`plt.title()`)
#     - the object_oriented methods (`ax.bar()`,`ax.set_title()`)
#
#
#
# - The 2 syntaxes can be confusing at first and cause problems & odd results when mixed together.
#     - Learn about some of the problems when mixing types.
#     - Example: see how plt.title()/plt.xlabel(),etc. can behave strangely in subplots.
#
#     - **Bookmark this article, its the best explanation of how matploblib'S 2 interfaces work:**
# > ["Artist" in Matplotlib - something I wanted to know before spending tremendous hours on googling how-tos.](https://dev.to/skotaro/artist-in-matplotlib---something-i-wanted-to-know-before-spending-tremendous-hours-on-googling-how-tos--31oo)<br>
#
# - [My Blog Post on Making Customized Figures in seaborn](https://jirvingphd.github.io/harnessing_seaborn_subplots_for_eda)
#     - This covers some concepts we didn't have time to cover, like ticklabel formatters.

# %% [markdown]
# #### **Matplotlib Offical Documentation**
#
# - [Markers](https://matplotlib.org/3.1.1/api/markers_api.html)
# - [Colors](https://matplotlib.org/3.1.0/gallery/color/named_colors.html )
# - [Text](https://matplotlib.org/3.1.0/tutorials/text/text_intro.html )
# - [Text Properties](https://matplotlib.org/3.1.1/tutorials/text/text_props.html)

# %% [markdown]
# ## Matplotlib Anatomy / Structure

# %% [markdown]
# <center><img src="https://raw.githubusercontent.com/jirvingphd/fsds_100719_cohort_notes/master/images/matplotlib_anatomy.png" width=400></center>
#
# - Matplotlib Figures are composed of 3 different objects:
#     - `Figure` is the largest bucket and contains everything else. It is like a picture frame without any actual images in it.
#   - `Axes` are the actual plot / image inside of the Figure / frame.
#         - this is the same `ax` as in `fig, ax = plt.subplots()` and that is returned when you create a Pandas or Seaborn figure.
#         - There is an 'Axes` for each subplot in the Figure
#         - `Axes` contain information about the titles, labels, grid,background, they also contain an. See the figure below for the contents of `Axes`

# %% [markdown]
#
# - Inside Axes there is an `Axis` which is further divided into an `Axis.xaxis` and an `Axis.yaxis` that contain the ticks and the tick lables.
#     <center><img src="https://raw.githubusercontent.com/jirvingphd/fsds_100719_cohort_notes/master/images/matplotlib_Axes_layout2.png" width=500></center>

# %% [markdown]
# # Using Matplotlib.pyplot

# %% [markdown]
# - https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.html
# - Pyplot figures don't need to be created first. You can just call one of the plotting functions `plt.bar/plot/scatter/etc`
# - Any `plt` commands entered in the same cell will happen on the same plot.
#
# ```python
# import matplotlib.pyplot as plt
# plt.plot(x,y)
# plt.hist(x)
# plt.scatter(x,y)
# plt.bar(x, height) #x= group/label, height = bar height/ y
#
# ```
#
# - BUT if you want to specify figsize, you have to you create the figure first with `plt.figure(figsize=(W,H))` where width and height are numbers.
#
# ```python
# fig = plt.figure(figsize=(10,5))
# plt.plot(x,y)
# ```

# %%
# !pip install -U fsds
from fsds.imports import *
# Out:
# fsds v0.2.22 loaded.  Read the docs: https://fs-ds.readthedocs.io/en/latest/
# <style  type="text/css" >
# </style><table id="T_a8464cfa_c840_11ea_bc90_acde48001122" ><caption>Loaded Packages and Handles</caption><thead>    <tr>        <th class="col_heading level0 col0" >Handle</th>        <th class="col_heading level0 col1" >Package</th>        <th class="col_heading level0 col2" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row0_col0" class="data row0 col0" >dp</td>
#                         <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row0_col1" class="data row0 col1" >IPython.display</td>
#                         <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row0_col2" class="data row0 col2" >Display modules with helpful display and clearing commands.</td>
#             </tr>
#             <tr>
#                                 <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row1_col0" class="data row1 col0" >fs</td>
#                         <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row1_col1" class="data row1 col1" >fsds</td>
#                         <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row1_col2" class="data row1 col2" >Custom data science bootcamp student package</td>
#             </tr>
#             <tr>
#                                 <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row2_col0" class="data row2 col0" >mpl</td>
#                         <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row2_col1" class="data row2 col1" >matplotlib</td>
#                         <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row2_col2" class="data row2 col2" >Matplotlib's base OOP module with formatting artists</td>
#             </tr>
#             <tr>
#                                 <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row3_col0" class="data row3 col0" >plt</td>
#                         <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row3_col1" class="data row3 col1" >matplotlib.pyplot</td>
#                         <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row3_col2" class="data row3 col2" >Matplotlib's matlab-like plotting module</td>
#             </tr>
#             <tr>
#                                 <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row4_col0" class="data row4 col0" >np</td>
#                         <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row4_col1" class="data row4 col1" >numpy</td>
#                         <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row4_col2" class="data row4 col2" >scientific computing with Python</td>
#             </tr>
#             <tr>
#                                 <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row5_col0" class="data row5 col0" >pd</td>
#                         <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row5_col1" class="data row5 col1" >pandas</td>
#                         <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row5_col2" class="data row5 col2" >High performance data structures and tools</td>
#             </tr>
#             <tr>
#                                 <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row6_col0" class="data row6 col0" >sns</td>
#                         <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row6_col1" class="data row6 col1" >seaborn</td>
#                         <td id="T_a8464cfa_c840_11ea_bc90_acde48001122row6_col2" class="data row6 col2" >High-level data visualization library based on matplotlib</td>
#             </tr>
#     </tbody></table>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# [i] Pandas .iplot() method activated.

# %%
df = fs.datasets.load_autompg()
X = df['horsepower'].copy()
y = df['mpg'].copy()
# Out:
# [i] Source url with details: https://www.kaggle.com/uciml/autompg-dataset
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
## Plot x vs y and add ax labels
plt.scatter(X,y)
plt.xlabel('HorsePower')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %%
## Make larger figure first 
plt.figure(figsize=(10,6))

##Plot x vs y and add ax labels
plt.scatter(X,y)
plt.xlabel('HorsePower')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %% [markdown]
# - Now let's make the ax labels and ticks more legible

# %%
## Make larger figure first 
plt.figure(figsize=(10,6))

##Plot x vs y and add ax labels
plt.scatter(X,y)

label_kws = {'size':14,'family':'serif'}
plt.xlabel('HorsePower',fontdict = label_kws)
plt.ylabel('MPG',fontdict=label_kws)
plt.tick_params(axis='both',labelsize=12)

# %% [markdown]
# - But what if I want to save my figure into a dictionary or list?

# %%
plt.bar(df['model year'],df['mpg'])#top_10.index,top_10.values)
plt.ylabel('MPG')
plt.xlabel('Model Year')
plt.title('MPG by Model Year')
# plt.tick_params(axis='x',labelrotation=45)
# Out:
# Text(0.5, 1.0, 'MPG by Model Year')

# %% [markdown]
# # Using Matplotlib's Object-Oriented Interface

# %% [markdown]
# - Create new figures by using `fig,ax=plt.subplots()` to create a figure _first_
#     - If do not specify `nrows` or `ncols` it produces one ax inside the figure.
#
#     - If you create subplots by passing it more rows or columns, then ax becomes a *list* of the axes.
#     `fig, axes = plt.subplots(ncols=2)`
#
# - Plotting commands are then called directly by the `ax` as a method.
# i.e. `ax.plot()`
#
# - Adding text and styling is done via a different set of commands, which are also called directly by the `ax`, and start with `.set_`
# - The command for setting the title changes from `plt.title` to `ax.set_title()`
# - `ax.set_ylabel()`
# - etc.

# %%
fig,ax = plt.subplots()
ax.bar(df['model year'],df['mpg'])
ax.set(ylabel='MPG', xlabel='Model Year',title = 'MPG by Model Year')
# Out:
# [Text(0, 0.5, 'MPG'),
#  Text(0.5, 0, 'Model Year'),
#  Text(0.5, 1.0, 'MPG by Model Year')]

# %%
ax.set_xticklabels(ax.get_xticklabels(),fontdict=dict(rotation=45,
                  ha='right'))
fig

# %% [markdown]
# ## Using Pandas or Seaborn

# %% [markdown]
# - *Matplotlib is the backbone of plotting in python.*<br>
# - Many packages ( `statsmodels`,`seaborn`,`pandas`,`plotly`) use a matplotlib backbone to make complex and aesthetically pleasing visuals.<br>
#     - i.e. pandas `df.plot()/df.scatter()` are using matplotlib's .plot(), .scatter(), but wrapped
#     - i.e. seaborn's sns.regplot() is a matplotlib plt.scatter() and a plt.plot() line

# %%
df.plot.scatter('horsepower','mpg',figsize=(10,6))

# %%
top_10 = df.groupby('car name').mean().sort_values('mpg',ascending=False)['mpg'].head(10)
top_10
# Out:
# car name
# mazda glc                          46.6
# honda civic 1500 gl                44.6
# vw rabbit c (diesel)               44.3
# vw pickup                          44.0
# vw dasher (diesel)                 43.4
# volkswagen rabbit custom diesel    43.1
# datsun b210 gx                     39.4
# toyota starlet                     39.1
# plymouth champ                     39.0
# toyota corolla tercel              38.1
# Name: mpg, dtype: float64

# %%
## Plot a horizontal bar plot
top_10.plot(kind='barh')

# %% [markdown]
# ### OOP Matplotlib + Pandas

# %%
ax = top_10.plot(kind='bar')
ax.set(ylabel='mpg', xlabel='Car Name',title = 'Top 10 MPG Vehicles');
ax.set_xticklabels(ax.get_xticklabels(),fontdict=dict(rotation=45,ha='right'));

# %%
def plot_top_10():

    ax = top_10.plot(kind='bar')
    ax.set(ylabel='mpg', xlabel='Car Name',title = 'Top 10 MPG Vehicles');
    fig = ax.get_figure()
    return fig,ax

# %%
plot_top_10();

# %% [markdown]
# - We can customize the text properties for our labels using the `fontdict` parameter in our text/labeling functiopns
#
#     - font_dict is a dictionary with a keyword that specifies what property to change and a value for that property
#     - [See this link for available properties](https://matplotlib.org/3.1.1/tutorials/text/text_props.html?highlight=text)

# %%
## Fixing and customizing fonts
fig,ax  = plot_top_10()
xticklabel_fonts = dict(rotation=45,weight='bold',ha='right')
yticklabel_fonts = dict(weight='bold',ha='right')
title_fonts = dict(family='serif',weight='bold',size=20)
axlabels =  dict(weight='bold',ha='right',size=14)

ax.set_title(ax.get_title(),fontdict=title_fonts)
ax.set_xticklabels(ax.get_xticklabels(),fontdict=xticklabel_fonts)
ax.set_yticklabels(ax.get_yticklabels(),fontdict=yticklabel_fonts)
ax.set_xlabel(ax.get_xlabel(), fontdict=axlabels)
ax.set_ylabel(ax.get_ylabel(),fontdict = axlabels)
fig = ax.get_figure()
fig

# %% [markdown]
# ## Matplotlib Styles

# %% [markdown]
# You can specify a style sheet for pandas, which will change the default visual style for all plots.
# - **[Visit the gallery for a preview of the styles available.](https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html)**
#
#
# ```python
# import matplotlib.pyplot as plt
# plt.style.use('style-name')
# ```
#
# Use a context` block to apply a style to that figure only:
# ```python
# with plt.style.context('style-name'):
#     plt.plot()
# ```

# %%
style_names = plt.style.available

print("[i] Available matplotlib styles:")
[print('\t',x) for x in style_names];
# Out:
# [i] Available matplotlib styles:
# 	 Solarize_Light2
# 	 _classic_test_patch
# 	 bmh
# 	 classic
# 	 dark_background
# 	 fast
# 	 fivethirtyeight
# 	 ggplot
# 	 grayscale
# 	 seaborn
# 	 seaborn-bright
# 	 seaborn-colorblind
# 	 seaborn-dark
# 	 seaborn-dark-palette
# 	 seaborn-darkgrid
# 	 seaborn-deep
# 	 seaborn-muted
# 	 seaborn-notebook
# 	 seaborn-paper
# 	 seaborn-pastel
# 	 seaborn-poster
# 	 seaborn-talk
# 	 seaborn-ticks
# 	 seaborn-white
# 	 seaborn-whitegrid
# 	 tableau-colorblind10

# %%
# Loop through style names
for style in style_names:
    
    # Use context manager to apply style to ONLY this figure
    with plt.style.context(style):
        fig,ax = plot_top_10()
        ax.set_ylabel(ax.get_title())
        ax.set_title(f"Style: '{style}'")
        plt.show()

# %% [markdown]
# # Previously on...  *Section 05*

# %% [markdown]
# ## Prior Activity: Project - Data Cleaning

# %% [markdown]
# - [Lesson](https://learn.co/tracks/module-1-data-science-career-2-1/intro-to-data-with-python-and-sql/section-05-data-cleaning-in-pandas/project-data-cleaning)
#
# - [Solution](https://github.com/learn-co-students/dsc-data-cleaning-project-onl01-dtsc-pt-041320/tree/solution)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install -U pandas 
import pandas as pd
pd.__version__
# Out:
# '1.0.1'

# %%
# !pip install -U matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-talk')
mpl.__version__
# Out:
# '3.2.2'

# %%
# !pip install -U seaborn
import seaborn as sns
import numpy as np
sns.__version__
# Out:
# '0.10.1'

# %% [markdown]
# For this lab, our dataset is split among two different sources -- `'heroes_information.csv'` and `'super_hero_powers.csv'`.
#
# Use pandas to read in each file and store them in DataFrames in the appropriate variables below. Then, display the `.head()` of each to ensure that everything loaded correctly.

# %%
pd.set_option('display.max_columns',0)
pd.set_option('display.max_rows',0)
# pd.set_option('display')

# %%
heroes_df = pd.read_csv('../sect_05/heroes_information.csv',index_col=0)
powers_df = pd.read_csv('../sect_05/super_hero_powers.csv')

display(heroes_df.head(), powers_df.head())
# Out:
#           name Gender Eye color  ... Skin color Alignment  Weight
# 0       A-Bomb   Male    yellow  ...          -      good   441.0
# 1   Abe Sapien   Male      blue  ...       blue      good    65.0
# 2     Abin Sur   Male      blue  ...        red      good    90.0
# 3  Abomination   Male     green  ...          -       bad   441.0
# 4      Abraxas   Male      blue  ...          -       bad   -99.0
#
# [5 rows x 10 columns]
#     hero_names  Agility  ...  Omnipresent  Omniscient
# 0      3-D Man     True  ...        False       False
# 1       A-Bomb    False  ...        False       False
# 2   Abe Sapien     True  ...        False       False
# 3     Abin Sur    False  ...        False       False
# 4  Abomination    False  ...        False       False
#
# [5 rows x 168 columns]

# %%
powers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Columns: 168 entries, hero_names to Omniscient
# dtypes: bool(167), object(1)
# memory usage: 114.1+ KB

# %% [markdown]
# It looks as if the heroes information dataset contained an index column.  We did not specify that this dataset contained an index column, because we hadn't seen it yet. Pandas does not know how to tell apart an index column from any other data, so it stored it with the column name `Unnamed: 0`.
#
# Our DataFrame provided row indices by default, so this column is not needed.  Drop it from the DataFrame in place in the cell below, and then display the head of `heroes_df` to ensure that it worked properly.

# %%
# heroes_df.drop('Unnamed: 0',axis=1, inplace=True)
# heroes_df

# %% [markdown]
# ## Familiarize yourself with the dataset

# %% [markdown]
# The first step in our Exploratory Data Analysis will be to get familiar with the data.  This step includes:
#
# * Understanding the dimensionality of your dataset
# * Investigating what type of data it contains, and the data types used to store it
# * Discovering how missing values are encoded, and how many there are
# * Getting a feel for what information it does and doesn't contain
#
# In the cell below, get the descriptive statistics of each DataFrame.

# %%
heroes_df.shape
# Out:
# (734, 10)

# %%
heroes_df.dtypes
# Out:
# name           object
# Gender         object
# Eye color      object
# Race           object
# Hair color     object
# Height        float64
# Publisher      object
# Skin color     object
# Alignment      object
# Weight        float64
# dtype: object

# %%
heroes_df.isna().sum()
# Out:
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         2
# dtype: int64

# %%
def check_df(df,head=False,head_n=3,describe=False,get_df=False):

    
    ## Save df info
    info = {
        'col #': range(len(df.columns)),
        'col name':df.columns,
        'dtypes':df.dtypes,'nunique':df.nunique(),
       'null values':df.isna().sum(),
        '% null':(df.isna().sum()/len(df)).round(2)

    }

    ## Make into a df and reset_index:
    info_df =pd.DataFrame(info).set_index('col name')#reset_index()
    
    if head:
        display(df.head(head_n).style.set_caption(f'First {head_n} rows'))
        info_df = info_df.T
        
    with pd.option_context('display.max_rows',200):
        display(info_df.style.set_caption("Column Statistics"))#.sort_values(sort_by,ascending=True))
        
    if describe:
        display(df.describe().round(3).style.set_caption('.describe()'))
             
    if get_df:
         return info_df

# %%
check_df(heroes_df,head=False,describe=False)#,'% null')
# Out:
# <style  type="text/css" >
# </style><table id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626" ><caption>Column Statistics</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >col #</th>        <th class="col_heading level0 col1" >dtypes</th>        <th class="col_heading level0 col2" >nunique</th>        <th class="col_heading level0 col3" >null values</th>        <th class="col_heading level0 col4" >% null</th>    </tr>    <tr>        <th class="index_name level0" >col name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626level0_row0" class="row_heading level0 row0" >name</th>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row0_col1" class="data row0 col1" >object</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row0_col2" class="data row0 col2" >715</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row0_col4" class="data row0 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626level0_row1" class="row_heading level0 row1" >Gender</th>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row1_col1" class="data row1 col1" >object</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row1_col2" class="data row1 col2" >3</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row1_col4" class="data row1 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626level0_row2" class="row_heading level0 row2" >Eye color</th>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row2_col1" class="data row2 col1" >object</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row2_col2" class="data row2 col2" >23</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row2_col4" class="data row2 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626level0_row3" class="row_heading level0 row3" >Race</th>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row3_col1" class="data row3 col1" >object</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row3_col2" class="data row3 col2" >62</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row3_col3" class="data row3 col3" >0</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row3_col4" class="data row3 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626level0_row4" class="row_heading level0 row4" >Hair color</th>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row4_col1" class="data row4 col1" >object</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row4_col2" class="data row4 col2" >30</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row4_col3" class="data row4 col3" >0</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row4_col4" class="data row4 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626level0_row5" class="row_heading level0 row5" >Height</th>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row5_col1" class="data row5 col1" >float64</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row5_col2" class="data row5 col2" >54</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row5_col3" class="data row5 col3" >0</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row5_col4" class="data row5 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626level0_row6" class="row_heading level0 row6" >Publisher</th>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row6_col1" class="data row6 col1" >object</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row6_col2" class="data row6 col2" >24</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row6_col3" class="data row6 col3" >15</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row6_col4" class="data row6 col4" >0.020000</td>
#             </tr>
#             <tr>
#                         <th id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626level0_row7" class="row_heading level0 row7" >Skin color</th>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row7_col0" class="data row7 col0" >7</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row7_col1" class="data row7 col1" >object</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row7_col2" class="data row7 col2" >17</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row7_col3" class="data row7 col3" >0</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row7_col4" class="data row7 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626level0_row8" class="row_heading level0 row8" >Alignment</th>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row8_col0" class="data row8 col0" >8</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row8_col1" class="data row8 col1" >object</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row8_col2" class="data row8 col2" >4</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row8_col3" class="data row8 col3" >0</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row8_col4" class="data row8 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626level0_row9" class="row_heading level0 row9" >Weight</th>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row9_col0" class="data row9 col0" >9</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row9_col1" class="data row9 col1" >float64</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row9_col2" class="data row9 col2" >135</td>
#                         <td id="T_4147eb3e_c7d0_11ea_b147_4865ee12e626row9_col3" class="data row9 col3" >2</td>
#                         <td id="T_4147eb3e

# %%
heroes_df
# Out:
#                 name  Gender Eye color  ... Skin color Alignment  Weight
# 0             A-Bomb    Male    yellow  ...          -      good   441.0
# 1         Abe Sapien    Male      blue  ...       blue      good    65.0
# 2           Abin Sur    Male      blue  ...        red      good    90.0
# 3        Abomination    Male     green  ...          -       bad   441.0
# 4            Abraxas    Male      blue  ...          -       bad   -99.0
# 5      Absorbing Man    Male      blue  ...          -       bad   122.0
# 6        Adam Monroe    Male      blue  ...          -      good   -99.0
# 7       Adam Strange    Male      blue  ...          -      good    88.0
# 8           Agent 13  Female      blue  ...          -      good    61.0
# ..               ...     ...       ...  ...        ...       ...     ...
# 725             X-23  Female     green  ...          -      good    50.0
# 726            X-Man    Male      blue  ...          -      good    61.0
# 727      Yellow Claw    Male      blue  ...          -       bad    95.0
# 728     Yellowjacket    Male      blue  ...          -      good    83.0
# 729  Yellowjacket II  Female      blue  ...          -      good    52.0
# 730             Ymir    Male     white  ...      white      good   -99.0
# 731             Yoda    Male     brown  ...      green      good    17.0
# 732          Zatanna  Female      blue  ...          -      good    57.0
# 733             Zoom    Male       red  ...          -       bad    81.0
#
# [734 rows x 10 columns]

# %%
check_df(powers_df,'nunique')
# Out:
# <style  type="text/css" >
# </style><table id="T_4152dab4_c7d0_11ea_b8d4_4865ee12e626" ><caption>First 3 rows</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >hero_names</th>        <th class="col_heading level0 col1" >Agility</th>        <th class="col_heading level0 col2" >Accelerated Healing</th>        <th class="col_heading level0 col3" >Lantern Power Ring</th>        <th class="col_heading level0 col4" >Dimensional Awareness</th>        <th class="col_heading level0 col5" >Cold Resistance</th>        <th class="col_heading level0 col6" >Durability</th>        <th class="col_heading level0 col7" >Stealth</th>        <th class="col_heading level0 col8" >Energy Absorption</th>        <th class="col_heading level0 col9" >Flight</th>        <th class="col_heading level0 col10" >Danger Sense</th>        <th class="col_heading level0 col11" >Underwater breathing</th>        <th class="col_heading level0 col12" >Marksmanship</th>        <th class="col_heading level0 col13" >Weapons Master</th>        <th class="col_heading level0 col14" >Power Augmentation</th>        <th class="col_heading level0 col15" >Animal Attributes</th>        <th class="col_heading level0 col16" >Longevity</th>        <th class="col_heading level0 col17" >Intelligence</th>        <th class="col_heading level0 col18" >Super Strength</th>        <th class="col_heading level0 col19" >Cryokinesis</th>        <th class="col_heading level0 col20" >Telepathy</th>        <th class="col_heading level0 col21" >Energy Armor</th>        <th class="col_heading level0 col22" >Energy Blasts</th>        <th class="col_heading level0 col23" >Duplication</th>        <th class="col_heading level0 col24" >Size Changing</th>        <th class="col_heading level0 col25" >Density Control</th>        <th class="col_heading level0 col26" >Stamina</th>        <th class="col_heading level0 col27" >Astral Travel</th>        <th class="col_heading level0 col28" >Audio Control</th>        <th class="col_heading level0 col29" >Dexterity</th>        <th class="col_heading level0 col30" >Omnitrix</th>        <th class="col_heading level0 col31" >Super Speed</th>        <th class="col_heading level0 col32" >Possession</th>        <th class="col_heading level0 col33" >Animal Oriented Powers</th>        <th class="col_heading level0 col34" >Weapon-based Powers</th>        <th class="col_heading level0 col35" >Electrokinesis</th>        <th class="col_heading level0 col36" >Darkforce Manipulation</th>        <th class="col_heading level0 col37" >Death Touch</th>        <th class="col_heading level0 col38" >Teleportation</th>        <th class="col_heading level0 col39" >Enhanced Senses</th>        <th class="col_heading level0 col40" >Telekinesis</th>        <th class="col_heading level0 col41" >Energy Beams</th>        <th class="col_heading level0 col42" >Magic</th>        <th class="col_heading level0 col43" >Hyperkinesis</th>        <th class="col_heading level0 col44" >Jump</th>        <th class="col_heading level0 col45" >Clairvoyance</th>        <th class="col_heading level0 col46" >Dimensional Travel</th>        <th class="col_heading level0 col47" >Power Sense</th>        <th class="col_heading level0 col48" >Shapeshifting</th>        <th class="col_heading level0 col49" >Peak Human Condition</th>        <th class="col_heading level0 col50" >Immortality</th>        <th class="col_heading level0 col51" >Camouflage</th>        <th class="col_heading level0 col52" >Element Control</th>        <th class="col_heading level0 col53" >Phasing</th>        <th class="col_heading level0 col54" >Astral Projection</th>        <th class="col_heading level0 col55" >Electrical Transport</th>        <th class="col_heading level0 col56" >Fire Control</th>        <th class="col_heading level0 col57" >Projection</th>        <th class="col_heading level0 col58" >Summoning</th>        <th class="col_heading level0 col59" >Enhanced Memory</th>        <th class="col_heading l ...
# <style  type="text/css" >
# </style><table id="T_41580ca8_c7d0_11ea_a43d_4865ee12e626" ><caption>Column Statistics</caption><thead>    <tr>        <th class="index_name level0" >col name</th>        <th class="col_heading level0 col0" >hero_names</th>        <th class="col_heading level0 col1" >Agility</th>        <th class="col_heading level0 col2" >Accelerated Healing</th>        <th class="col_heading level0 col3" >Lantern Power Ring</th>        <th class="col_heading level0 col4" >Dimensional Awareness</th>        <th class="col_heading level0 col5" >Cold Resistance</th>        <th class="col_heading level0 col6" >Durability</th>        <th class="col_heading level0 col7" >Stealth</th>        <th class="col_heading level0 col8" >Energy Absorption</th>        <th class="col_heading level0 col9" >Flight</th>        <th class="col_heading level0 col10" >Danger Sense</th>        <th class="col_heading level0 col11" >Underwater breathing</th>        <th class="col_heading level0 col12" >Marksmanship</th>        <th class="col_heading level0 col13" >Weapons Master</th>        <th class="col_heading level0 col14" >Power Augmentation</th>        <th class="col_heading level0 col15" >Animal Attributes</th>        <th class="col_heading level0 col16" >Longevity</th>        <th class="col_heading level0 col17" >Intelligence</th>        <th class="col_heading level0 col18" >Super Strength</th>        <th class="col_heading level0 col19" >Cryokinesis</th>        <th class="col_heading level0 col20" >Telepathy</th>        <th class="col_heading level0 col21" >Energy Armor</th>        <th class="col_heading level0 col22" >Energy Blasts</th>        <th class="col_heading level0 col23" >Duplication</th>        <th class="col_heading level0 col24" >Size Changing</th>        <th class="col_heading level0 col25" >Density Control</th>        <th class="col_heading level0 col26" >Stamina</th>        <th class="col_heading level0 col27" >Astral Travel</th>        <th class="col_heading level0 col28" >Audio Control</th>        <th class="col_heading level0 col29" >Dexterity</th>        <th class="col_heading level0 col30" >Omnitrix</th>        <th class="col_heading level0 col31" >Super Speed</th>        <th class="col_heading level0 col32" >Possession</th>        <th class="col_heading level0 col33" >Animal Oriented Powers</th>        <th class="col_heading level0 col34" >Weapon-based Powers</th>        <th class="col_heading level0 col35" >Electrokinesis</th>        <th class="col_heading level0 col36" >Darkforce Manipulation</th>        <th class="col_heading level0 col37" >Death Touch</th>        <th class="col_heading level0 col38" >Teleportation</th>        <th class="col_heading level0 col39" >Enhanced Senses</th>        <th class="col_heading level0 col40" >Telekinesis</th>        <th class="col_heading level0 col41" >Energy Beams</th>        <th class="col_heading level0 col42" >Magic</th>        <th class="col_heading level0 col43" >Hyperkinesis</th>        <th class="col_heading level0 col44" >Jump</th>        <th class="col_heading level0 col45" >Clairvoyance</th>        <th class="col_heading level0 col46" >Dimensional Travel</th>        <th class="col_heading level0 col47" >Power Sense</th>        <th class="col_heading level0 col48" >Shapeshifting</th>        <th class="col_heading level0 col49" >Peak Human Condition</th>        <th class="col_heading level0 col50" >Immortality</th>        <th class="col_heading level0 col51" >Camouflage</th>        <th class="col_heading level0 col52" >Element Control</th>        <th class="col_heading level0 col53" >Phasing</th>        <th class="col_heading level0 col54" >Astral Projection</th>        <th class="col_heading level0 col55" >Electrical Transport</th>        <th class="col_heading level0 col56" >Fire Control</th>        <th class="col_heading level0 col57" >Projection</th>        <th class="col_heading level0 col58" >Summoning</th>        <th class="col_heading level0 col59" >Enhanced Memory</th>        <th cl ...

# %%
check_df(heroes_df)
# Out:
# <style  type="text/css" >
# </style><table id="T_415e8f92_c7d0_11ea_985a_4865ee12e626" ><caption>Column Statistics</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >col #</th>        <th class="col_heading level0 col1" >dtypes</th>        <th class="col_heading level0 col2" >nunique</th>        <th class="col_heading level0 col3" >null values</th>        <th class="col_heading level0 col4" >% null</th>    </tr>    <tr>        <th class="index_name level0" >col name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_415e8f92_c7d0_11ea_985a_4865ee12e626level0_row0" class="row_heading level0 row0" >name</th>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row0_col1" class="data row0 col1" >object</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row0_col2" class="data row0 col2" >715</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row0_col4" class="data row0 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_415e8f92_c7d0_11ea_985a_4865ee12e626level0_row1" class="row_heading level0 row1" >Gender</th>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row1_col1" class="data row1 col1" >object</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row1_col2" class="data row1 col2" >3</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row1_col4" class="data row1 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_415e8f92_c7d0_11ea_985a_4865ee12e626level0_row2" class="row_heading level0 row2" >Eye color</th>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row2_col1" class="data row2 col1" >object</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row2_col2" class="data row2 col2" >23</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row2_col4" class="data row2 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_415e8f92_c7d0_11ea_985a_4865ee12e626level0_row3" class="row_heading level0 row3" >Race</th>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row3_col1" class="data row3 col1" >object</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row3_col2" class="data row3 col2" >62</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row3_col3" class="data row3 col3" >0</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row3_col4" class="data row3 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_415e8f92_c7d0_11ea_985a_4865ee12e626level0_row4" class="row_heading level0 row4" >Hair color</th>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row4_col1" class="data row4 col1" >object</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row4_col2" class="data row4 col2" >30</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row4_col3" class="data row4 col3" >0</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row4_col4" class="data row4 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_415e8f92_c7d0_11ea_985a_4865ee12e626level0_row5" class="row_heading level0 row5" >Height</th>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row5_col1" class="data row5 col1" >float64</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row5_col2" class="data row5 col2" >54</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row5_col3" class="data row5 col3" >0</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row5_col4" class="data row5 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_415e8f92_c7d0_11ea_985a_4865ee12e626level0_row6" class="row_heading level0 row6" >Publisher</th>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row6_col1" class="data row6 col1" >object</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row6_col2" class="data row6 col2" >24</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row6_col3" class="data row6 col3" >15</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row6_col4" class="data row6 col4" >0.020000</td>
#             </tr>
#             <tr>
#                         <th id="T_415e8f92_c7d0_11ea_985a_4865ee12e626level0_row7" class="row_heading level0 row7" >Skin color</th>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row7_col0" class="data row7 col0" >7</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row7_col1" class="data row7 col1" >object</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row7_col2" class="data row7 col2" >17</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row7_col3" class="data row7 col3" >0</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row7_col4" class="data row7 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_415e8f92_c7d0_11ea_985a_4865ee12e626level0_row8" class="row_heading level0 row8" >Alignment</th>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row8_col0" class="data row8 col0" >8</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row8_col1" class="data row8 col1" >object</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row8_col2" class="data row8 col2" >4</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row8_col3" class="data row8 col3" >0</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row8_col4" class="data row8 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_415e8f92_c7d0_11ea_985a_4865ee12e626level0_row9" class="row_heading level0 row9" >Weight</th>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row9_col0" class="data row9 col0" >9</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row9_col1" class="data row9 col1" >float64</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row9_col2" class="data row9 col2" >135</td>
#                         <td id="T_415e8f92_c7d0_11ea_985a_4865ee12e626row9_col3" class="data row9 col3" >2</td>
#                         <td id="T_415e8f92

# %%
res = heroes_df.isna().sum()
res
# Out:
# name           0
# Gender         0
# Eye color      0
# Race           0
# Hair color     0
# Height         0
# Publisher     15
# Skin color     0
# Alignment      0
# Weight         2
# dtype: int64

# %%
heroes_df.describe().loc['mean']
# Out:
# Height    102.254087
# Weight     43.855191
# Name: mean, dtype: float64

# %%
res[res>0]
# Out:
# Publisher    15
# Weight        2
# dtype: int64

# %%
check_df(powers_df)
# Out:
# <style  type="text/css" >
# </style><table id="T_41683b14_c7d0_11ea_b97d_4865ee12e626" ><caption>Column Statistics</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >col #</th>        <th class="col_heading level0 col1" >dtypes</th>        <th class="col_heading level0 col2" >nunique</th>        <th class="col_heading level0 col3" >null values</th>        <th class="col_heading level0 col4" >% null</th>    </tr>    <tr>        <th class="index_name level0" >col name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_41683b14_c7d0_11ea_b97d_4865ee12e626level0_row0" class="row_heading level0 row0" >hero_names</th>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row0_col1" class="data row0 col1" >object</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row0_col2" class="data row0 col2" >667</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row0_col4" class="data row0 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_41683b14_c7d0_11ea_b97d_4865ee12e626level0_row1" class="row_heading level0 row1" >Agility</th>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row1_col1" class="data row1 col1" >bool</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row1_col2" class="data row1 col2" >2</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row1_col4" class="data row1 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_41683b14_c7d0_11ea_b97d_4865ee12e626level0_row2" class="row_heading level0 row2" >Accelerated Healing</th>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row2_col1" class="data row2 col1" >bool</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row2_col2" class="data row2 col2" >2</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row2_col4" class="data row2 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_41683b14_c7d0_11ea_b97d_4865ee12e626level0_row3" class="row_heading level0 row3" >Lantern Power Ring</th>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row3_col1" class="data row3 col1" >bool</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row3_col2" class="data row3 col2" >2</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row3_col3" class="data row3 col3" >0</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row3_col4" class="data row3 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_41683b14_c7d0_11ea_b97d_4865ee12e626level0_row4" class="row_heading level0 row4" >Dimensional Awareness</th>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row4_col1" class="data row4 col1" >bool</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row4_col2" class="data row4 col2" >2</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row4_col3" class="data row4 col3" >0</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row4_col4" class="data row4 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_41683b14_c7d0_11ea_b97d_4865ee12e626level0_row5" class="row_heading level0 row5" >Cold Resistance</th>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row5_col1" class="data row5 col1" >bool</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row5_col2" class="data row5 col2" >2</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row5_col3" class="data row5 col3" >0</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row5_col4" class="data row5 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_41683b14_c7d0_11ea_b97d_4865ee12e626level0_row6" class="row_heading level0 row6" >Durability</th>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row6_col1" class="data row6 col1" >bool</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row6_col2" class="data row6 col2" >2</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row6_col3" class="data row6 col3" >0</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row6_col4" class="data row6 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_41683b14_c7d0_11ea_b97d_4865ee12e626level0_row7" class="row_heading level0 row7" >Stealth</th>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row7_col0" class="data row7 col0" >7</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row7_col1" class="data row7 col1" >bool</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row7_col2" class="data row7 col2" >2</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row7_col3" class="data row7 col3" >0</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row7_col4" class="data row7 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_41683b14_c7d0_11ea_b97d_4865ee12e626level0_row8" class="row_heading level0 row8" >Energy Absorption</th>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row8_col0" class="data row8 col0" >8</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row8_col1" class="data row8 col1" >bool</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row8_col2" class="data row8 col2" >2</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row8_col3" class="data row8 col3" >0</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row8_col4" class="data row8 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_41683b14_c7d0_11ea_b97d_4865ee12e626level0_row9" class="row_heading level0 row9" >Flight</th>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row9_col0" class="data row9 col0" >9</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row9_col1" class="data row9 col1" >bool</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row9_col2" class="data row9 col2" >2</td>
#                         <td id="T_41683b14_c7d0_11ea_b97d_4865ee12e626row9_col3" class="data row9 col3" >0</td>

# %%
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 734 entries, 0 to 733
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        734 non-null    object
#  1   Gender      734 non-null    object
#  2   Eye color   734 non-null    object
#  3   Race        734 non-null    object
#  4   Hair color  734 non-null    object
#  5   Height      734 non-null    float64
#  6   Publisher   719 non-null    object
#  7   Skin color  734 non-null    object
#  8   Alignment   734 non-null    object
#  9   Weight      732 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 63.1+ KB

# %%
heroes_df.dtypes.loc[heroes_df.dtypes=='object'].index
# Out:
# Index(['name', 'Gender', 'Eye color', 'Race', 'Hair color', 'Publisher',
#        'Skin color', 'Alignment'],
#       dtype='object')

# %%
str_cols = heroes_df.select_dtypes('object').columns
str_cols
# Out:
# Index(['name', 'Gender', 'Eye color', 'Race', 'Hair color', 'Publisher',
#        'Skin color', 'Alignment'],
#       dtype='object')

# %%
for col in str_cols:
    display(heroes_df[col].value_counts(normalize=True,dropna=False))
# heroes_df[col].value_counts()
# Out:
# Goliath             0.004087
# Spider-Man          0.004087
# Vindicator          0.002725
# Blizzard            0.002725
# Firestorm           0.002725
# Atlas               0.002725
# Namor               0.002725
# Batman              0.002725
# Black Canary        0.002725
# Blue Beetle         0.002725
# Captain Marvel      0.002725
# Speedy              0.002725
#                       ...
# Abraxas             0.001362
# Sylar               0.001362
# Lady Deathstrike    0.001362
# Deadman             0.001362
# Michelangelo        0.001362
# Big Barda           0.001362
# Gog                 0.001362
# Red Skull           0.001362
# Beetle              0.001362
# Indiana Jones       0.001362
# Scorpia             0.001362
# Jessica Cruz        0.001362
# Name: name, Length: 715, dtype: float64
# Male      0.688011
# Female    0.272480
# -         0.039510
# Name: Gender, dtype: float64
# blue                       0.306540
# -                          0.234332
# brown                      0.171662
# green                      0.099455
# red                        0.062670
# black                      0.031335
# yellow                     0.025886
# white                      0.023161
# hazel                      0.008174
# grey                       0.008174
# purple                     0.005450
# gold                       0.004087
# amber                      0.002725
# violet                     0.002725
# yellow (without irises)    0.002725
# silver                     0.001362
# white / red                0.001362
# blue / white               0.001362
# indigo                     0.001362
# yellow / red               0.001362
# yellow / blue              0.001362
# bown                       0.001362
# green / blue               0.001362
# Name: Eye color, dtype: float64
# -                     0.414169
# Human                 0.283379
# Mutant                0.085831
# God / Eternal         0.019074
# Cyborg                0.014986
# Human / Radiation     0.014986
# Symbiote              0.012262
# Android               0.012262
# Kryptonian            0.009537
# Alien                 0.009537
# Demon                 0.008174
# Atlantean             0.006812
#                         ...
# Icthyo Sapien         0.001362
# Talokite              0.001362
# Zombie                0.001362
# Korugaran             0.001362
# Clone                 0.001362
# Kaiju                 0.001362
# Dathomirian Zabrak    0.001362
# Tamaranean            0.001362
# Maiar                 0.001362
# Czarnian              0.001362
# Strontian             0.001362
# Luphomoid             0.001362
# Name: Race, Length: 62, dtype: float64
# -                   0.234332
# Black               0.215259
# Blond               0.134877
# Brown               0.117166
# No Hair             0.102180
# Red                 0.069482
# White               0.031335
# Auburn              0.017711
# Green               0.010899
# Strawberry Blond    0.009537
# Grey                0.006812
# Purple              0.006812
#                       ...
# Orange              0.002725
# Brownn              0.001362
# Red / Orange        0.001362
# Indigo              0.001362
# Gold                0.001362
# Red / Grey          0.001362
# Magenta             0.001362
# Orange / White      0.001362
# Black / Blue        0.001362
# Red / White         0.001362
# Brown / Black       0.001362
# Pink                0.001362
# Name: Hair color, Length: 30, dtype: float64
# Marvel Comics        0.528610
# DC Comics            0.292916
# NBC - Heroes         0.025886
# Dark Horse Comics    0.024523
# NaN                  0.020436
# Image Comics         0.019074
# George Lucas         0.019074
# HarperCollins        0.008174
# Star Trek            0.008174
# Team Epic TV         0.006812
# SyFy                 0.006812
# ABC Studios          0.005450
#                        ...
# Shueisha             0.005450
# IDW Publishing       0.005450
# Wildstorm            0.004087
# Sony Pictures        0.002725
# Rebellion            0.001362
# South Park           0.001362
# Universal Studios    0.001362
# J. K. Rowling        0.001362
# J. R. R. Tolkien     0.001362
# Hanna-Barbera        0.001362
# Microsoft            0.001362
# Titan Books          0.001362
# Name: Publisher, Length: 25, dtype: float64
# -                 0.901907
# green             0.028610
# blue              0.012262
# red               0.012262
# white             0.009537
# grey              0.006812
# silver            0.006812
# purple            0.004087
# gold              0.004087
# yellow            0.002725
# pink              0.002725
# orange            0.001362
# orange / white    0.001362
# blue-white        0.001362
# red / black       0.001362
# gray              0.001362
# black             0.001362
# Name: Skin color, dtype: float64
# good       0.675749
# bad        0.282016
# neutral    0.032698
# -          0.009537
# Name: Alignment, dtype: float64

# %%
to_replace={'-':np.nan}
heroes_df['Alignment'].replace(to_replace).value_counts(dropna=False)
# Out:
# good       496
# bad        207
# neutral     24
# NaN          7
# Name: Alignment, dtype: int64

# %%
for col in str_cols: 
    heroes_df[col] = heroes_df[col].replace(to_replace)

# %%
heroes_df.isna().sum()
# Out:
# name            0
# Gender         29
# Eye color     172
# Race          304
# Hair color    172
# Height          0
# Publisher      15
# Skin color    662
# Alignment       7
# Weight          2
# dtype: int64

# %% [markdown]
# ## Dealing with missing values

# %% [markdown]
# Starting in the cell below, detect and deal with any missing values in either DataFrame. Then, explain your methodology for detecting and dealing with outliers in the markdown section below. Be sure to explain your strategy for dealing with missing values in numeric columns, as well as your strategy for dealing with missing values in non-numeric columns.
#
# Note that if you need to add more cells to write code in, you can do this by:
#
# **1.** Highlighting a cell and then pressing `ESC` to enter command mode.
# **2.** Press `A` to add a cell above the highlighted cell, or `B` to add a cell below the highlighted cell.
#
# Describe your strategy below this line:
# ____________________________________________________________________________________________________________________________

# %%
heroes_df['Weight'] = heroes_df['Weight'].fillna(heroes_df['Weight'].median())

# %%
heroes_df.isna().sum()
# Out:
# name            0
# Gender         29
# Eye color     172
# Race          304
# Hair color    172
# Height          0
# Publisher      15
# Skin color    662
# Alignment       7
# Weight          0
# dtype: int64

# %%
import missingno as ms
ms.matrix(heroes_df)

# %%
heroes_df.isna().sum()
# Out:
# name            0
# Gender         29
# Eye color     172
# Race          304
# Hair color    172
# Height          0
# Publisher      15
# Skin color    662
# Alignment       7
# Weight          0
# dtype: int64

# %%
# heroes_df.mode(axis=1)

# %%
heroes_df['Alignment'].value_counts().index[0]
# Out:
# 'good'

# %%
for col in str_cols:
    val_counts = heroes_df[col].value_counts()
    top_class = val_counts.index[0]
    heroes_df[col] = heroes_df[col].fillna(top_class)

# %%
heroes_df['Eye color'].value_counts(dropna=False)
# Out:
# blue                       397
# brown                      126
# green                       73
# red                         46
# black                       23
# yellow                      19
# white                       17
# hazel                        6
# grey                         6
# purple                       4
# gold                         3
# amber                        2
# violet                       2
# yellow (without irises)      2
# silver                       1
# white / red                  1
# blue / white                 1
# indigo                       1
# yellow / red                 1
# yellow / blue                1
# bown                         1
# green / blue                 1
# Name: Eye color, dtype: int64

# %%
heroes_df.isna().sum()
# Out:
# name          0
# Gender        0
# Eye color     0
# Race          0
# Hair color    0
# Height        0
# Publisher     0
# Skin color    0
# Alignment     0
# Weight        0
# dtype: int64

# %%
# ms.matrix(powers_df)

# %% [markdown]
# ## 07/17: Sect 05 Continued

# %%
## Let's check out numerical columnsß
heroes_df.describe().round(2)
# Out:
#        Height  Weight
# count  734.00  734.00
# mean   102.25   43.90
# std    139.62  130.65
# min    -99.00  -99.00
# 25%    -99.00  -99.00
# 50%    175.00   62.00
# 75%    185.00   90.00
# max    975.00  900.00

# %%
heroes_df.hist(bins='auto',figsize=(10,4));

# %%
heroes_df = heroes_df.replace({-99.0:np.nan})
heroes_df.hist(bins='auto',figsize=(10,4));
heroes_df.isna().sum()/len(heroes_df)
# Out:
# name          0.000000
# Gender        0.000000
# Eye color     0.000000
# Race          0.000000
# Hair color    0.000000
# Height        0.295640
# Publisher     0.000000
# Skin color    0.000000
# Alignment     0.000000
# Weight        0.322888
# dtype: float64

# %%
medians = heroes_df.groupby('Gender').median()
medians
# Out:
#         Height  Weight
# Gender
# Female   170.0    58.0
# Male     185.0    90.0

# %%
heroes_df.isna().sum()
# Out:
# name            0
# Gender          0
# Eye color       0
# Race            0
# Hair color      0
# Height        217
# Publisher       0
# Skin color      0
# Alignment       0
# Weight        237
# dtype: int64

# %%
def fill_height_weight(row):
    if np.isnan(row['Height']):
        row['Height'] = medians.loc[row['Gender'],'Height'].copy()
        
    if np.isnan(row['Weight']):
        row['Weight'] = medians.loc[row['Gender'],'Weight'].copy()
    return row

# %%
row = heroes_df.iloc[4]
np.isnan(row['Height'])# ==
# Out:
# True

# %%
heroes_df = heroes_df.apply(fill_height_weight,axis=1)
heroes_df
# Out:
#                 name  Gender Eye color  ... Skin color Alignment  Weight
# 0             A-Bomb    Male    yellow  ...      green      good   441.0
# 1         Abe Sapien    Male      blue  ...       blue      good    65.0
# 2           Abin Sur    Male      blue  ...        red      good    90.0
# 3        Abomination    Male     green  ...      green       bad   441.0
# 4            Abraxas    Male      blue  ...      green       bad    90.0
# 5      Absorbing Man    Male      blue  ...      green       bad   122.0
# 6        Adam Monroe    Male      blue  ...      green      good    90.0
# 7       Adam Strange    Male      blue  ...      green      good    88.0
# 8           Agent 13  Female      blue  ...      green      good    61.0
# ..               ...     ...       ...  ...        ...       ...     ...
# 725             X-23  Female     green  ...      green      good    50.0
# 726            X-Man    Male      blue  ...      green      good    61.0
# 727      Yellow Claw    Male      blue  ...      green       bad    95.0
# 728     Yellowjacket    Male      blue  ...      green      good    83.0
# 729  Yellowjacket II  Female      blue  ...      green      good    52.0
# 730             Ymir    Male     white  ...      white      good    90.0
# 731             Yoda    Male     brown  ...      green      good    17.0
# 732          Zatanna  Female      blue  ...      green      good    57.0
# 733             Zoom    Male       red  ...      green       bad    81.0
#
# [734 rows x 10 columns]

# %%
heroes_df.isna().sum()
# Out:
# name          0
# Gender        0
# Eye color     0
# Race          0
# Hair color    0
# Height        0
# Publisher     0
# Skin color    0
# Alignment     0
# Weight        0
# dtype: int64

# %%
dup_cols = ['name','Gender','Eye color','Race','Publisher']
heroes_df[heroes_df.duplicated(subset=dup_cols,keep=False)]
# Out:
#             name Gender Eye color  ... Skin color Alignment  Weight
# 49          Atom   Male      blue  ...      green      good    68.0
# 50          Atom   Male      blue  ...      green      good    90.0
# 68        Batman   Male      blue  ...      green      good    95.0
# 69        Batman   Male      blue  ...      green      good    77.0
# 115     Blizzard   Male      blue  ...      green       bad    90.0
# 116     Blizzard   Male      blue  ...      green       bad    90.0
# 122  Blue Beetle   Male      blue  ...      green      good    90.0
# 123  Blue Beetle   Male      blue  ...      green      good    90.0
# 289      Goliath   Male      blue  ...      green      good    90.0
# 290      Goliath   Male      blue  ...      green      good    90.0
# 291      Goliath   Male      blue  ...      green      good    90.0
#
# [11 rows x 10 columns]

# %%
heroes_df.drop_duplicates(keep='first',subset=dup_cols, inplace=True)
heroes_df[heroes_df.duplicated(subset=dup_cols,keep=False)]
# Out:
# Empty DataFrame
# Columns: [name, Gender, Eye color, Race, Hair color, Height, Publisher, Skin color, Alignment, Weight]
# Index: []

# %% [markdown]
# ## Joining, Grouping, and Aggregating
#
# In the cell below, join the two DataFrames.  Think about which sort of join you should use, as well as which columns you should join on.  Rename columns and manipulate as needed.
#
# **_HINT:_** Consider the possibility that the columns you choose to join on contain duplicate entries. If that is the case, devise a strategy to deal with the duplicates.
#
# **_HINT:_** If the join throws an error message, consider setting the column you want to join on as the index for each DataFrame.

# %%
powers_df#astype(int)
# Out:
#           hero_names  Agility  ...  Omnipresent  Omniscient
# 0            3-D Man     True  ...        False       False
# 1             A-Bomb    False  ...        False       False
# 2         Abe Sapien     True  ...        False       False
# 3           Abin Sur    False  ...        False       False
# 4        Abomination    False  ...        False       False
# 5            Abraxas    False  ...        False       False
# 6      Absorbing Man    False  ...        False       False
# 7        Adam Monroe    False  ...        False       False
# 8       Adam Strange    False  ...        False       False
# ..               ...      ...  ...          ...         ...
# 658     Wonder Woman    False  ...        False       False
# 659             X-23     True  ...        False       False
# 660            X-Man    False  ...        False       False
# 661     Yellowjacket    False  ...        False       False
# 662  Yellowjacket II    False  ...        False       False
# 663             Ymir    False  ...        False       False
# 664             Yoda     True  ...        False       False
# 665          Zatanna    False  ...        False       False
# 666             Zoom    False  ...        False       False
#
# [667 rows x 168 columns]

# %%
df = pd.merge(heroes_df,powers_df,how='inner',left_on='name',
         right_on='hero_names')
check_df(df)
# Out:
# <style  type="text/css" >
# </style><table id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626" ><caption>Column Statistics</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >col #</th>        <th class="col_heading level0 col1" >dtypes</th>        <th class="col_heading level0 col2" >nunique</th>        <th class="col_heading level0 col3" >null values</th>        <th class="col_heading level0 col4" >% null</th>    </tr>    <tr>        <th class="index_name level0" >col name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626level0_row0" class="row_heading level0 row0" >name</th>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row0_col1" class="data row0 col1" >object</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row0_col2" class="data row0 col2" >643</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row0_col4" class="data row0 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626level0_row1" class="row_heading level0 row1" >Gender</th>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row1_col1" class="data row1 col1" >object</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row1_col2" class="data row1 col2" >2</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row1_col4" class="data row1 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626level0_row2" class="row_heading level0 row2" >Eye color</th>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row2_col1" class="data row2 col1" >object</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row2_col2" class="data row2 col2" >22</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row2_col4" class="data row2 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626level0_row3" class="row_heading level0 row3" >Race</th>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row3_col1" class="data row3 col1" >object</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row3_col2" class="data row3 col2" >60</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row3_col3" class="data row3 col3" >0</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row3_col4" class="data row3 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626level0_row4" class="row_heading level0 row4" >Hair color</th>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row4_col1" class="data row4 col1" >object</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row4_col2" class="data row4 col2" >29</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row4_col3" class="data row4 col3" >0</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row4_col4" class="data row4 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626level0_row5" class="row_heading level0 row5" >Height</th>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row5_col1" class="data row5 col1" >float64</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row5_col2" class="data row5 col2" >51</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row5_col3" class="data row5 col3" >0</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row5_col4" class="data row5 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626level0_row6" class="row_heading level0 row6" >Publisher</th>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row6_col0" class="data row6 col0" >6</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row6_col1" class="data row6 col1" >object</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row6_col2" class="data row6 col2" >24</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row6_col3" class="data row6 col3" >0</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row6_col4" class="data row6 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626level0_row7" class="row_heading level0 row7" >Skin color</th>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row7_col0" class="data row7 col0" >7</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row7_col1" class="data row7 col1" >object</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row7_col2" class="data row7 col2" >16</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row7_col3" class="data row7 col3" >0</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row7_col4" class="data row7 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626level0_row8" class="row_heading level0 row8" >Alignment</th>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row8_col0" class="data row8 col0" >8</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row8_col1" class="data row8 col1" >object</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row8_col2" class="data row8 col2" >3</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row8_col3" class="data row8 col3" >0</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row8_col4" class="data row8 col4" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626level0_row9" class="row_heading level0 row9" >Weight</th>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row9_col0" class="data row9 col0" >9</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row9_col1" class="data row9 col1" >float64</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row9_col2" class="data row9 col2" >131</td>
#                         <td id="T_1d9fe162_c7d2_11ea_8e1b_4865ee12e626row9_col3" class="data row9 col3" >0</td>
#                         <td id="T_1d9fe162_

# %% [markdown]
# In the cell below, subset male and female heroes into different dataframes.  Create a scatterplot of the height and weight of each hero, with weight as the y-axis.  Plot both the male and female heroes subset into each dataframe, and make the color for each point in the scatterplot correspond to the gender of the superhero.

# %%
df.plot(kind='scatter',x='Height',y='Weight')

# %%
male_heroes_df = df.groupby('Gender').get_group("Male")
female_heroes_df = df.groupby("Gender").get_group("Female")
# display(male_heroes_df.head(),female_heroes_df.head())

# %%
fig,ax = plt.subplots(figsize=(10,6))
male_heroes_df.plot.scatter('Height','Weight',c='blue',label='Male',ax=ax)
female_heroes_df.plot.scatter('Height','Weight',c='pink',label='Female',ax=ax)

# %%
sns.scatterplot('Height','Weight',data=df,hue='Gender',size='')

# %%
sns.lmplot('Height','Weight',df,hue='Gender',aspect=2)##,size='Alignment')

# %% [markdown]
# ## Some Initial Investigation
#
# Next, slice the DataFrame as needed and visualize the distribution of heights and weights by gender.  You should have 4 total plots.
#
# In the cell below:
#
# * Slice the DataFrame into separate DataFrames by gender
# * Complete the `show_distplot()` function.  This helper function should take in a DataFrame, a string containing the gender we want to visualize, and the column name we want to visualize by gender. The function should display a distplot visualization from seaborn of the column/gender combination.
#
# Hint: Don't forget to check the [seaborn documentation for distplot](https://seaborn.pydata.org/generated/seaborn.distplot.html) if you have questions about how to use it correctly!

# %%
# fg.map(sns.distplot)

# %%
def show_distplot(dataframe, gender, column_name):
    pass

# %%
# Male Height

# %%
def show_distplot(dataframe, gender, column_name,plot_col):
    df_ = df.groupby(column_name).get_group(gender)
    ax = sns.distplot(df_[plot_col])
    ax.set_title(f"Grouped by {column_name}- ({gender})")

# %%
# Female Height

# %%
# Male Weight

# %%
# Female Weight

# %% [markdown]
# Discuss your findings from the plots above, with respect to the distribution of height and weight by gender.  Your explanation should include a discussion of any relevant summary statistics, including mean, median, mode, and the overall shape of each distribution.
#
# Write your answer below this line:
# ____________________________________________________________________________________________________________________________

# %% [markdown]
# ___

# %% [markdown]
# # ACTIVITY: Visualizing Super Heroes

# %% [markdown]
# ### Sample Question: Most Common Powers
#
# The rest of this notebook will be left to you to investigate the dataset by formulating your own questions, and then seeking answers using pandas and numpy.  Every answer should include some sort of visualization, when appropriate. Before moving on to formulating your own questions, use the dataset to answer the following questions about superhero powers:
#
# * What are the 5 most common powers overall?
# * What are the 5 most common powers in the Marvel Universe?
# * What are the 5 most common powers in the DC Universe?

# %%
power_cols = powers_df.drop(columns=['hero_names']).columns
power_cols
# Out:
# Index(['Agility', 'Accelerated Healing', 'Lantern Power Ring',
#        'Dimensional Awareness', 'Cold Resistance', 'Durability', 'Stealth',
#        'Energy Absorption', 'Flight', 'Danger Sense',
#        ...
#        'Web Creation', 'Reality Warping', 'Odin Force', 'Symbiote Costume',
#        'Speed Force', 'Phoenix Force', 'Molecular Dissipation',
#        'Vision - Cryo', 'Omnipresent', 'Omniscient'],
#       dtype='object', length=167)

# %%
power_counts = df[power_cols].sum(axis=0)
power_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-9d701b8700b2> in <module>
# ----> 1 power_counts = df[power_cols].sum(axis=0)
#       2 power_counts
#
# NameError: name 'df' is not defined

# %%
top_10 = power_counts.sort_values(ascending=False).head(10)#.plot(kind='bar')
top_10

# %% [markdown]
# ### Your Own Investigation
#
# For the remainder of this lab, you'll be focusing on coming up with and answering your own question, just like we did above.  Your question should not be overly simple, and should require both descriptive statistics and data visualization to answer.  In case you're unsure of what questions to ask, some sample questions have been provided below.
#
# Pick one of the following questions to investigate and answer, or come up with one of your own!
#
# * Which powers have the highest chance of co-occurring in a hero (e.g. super strength and flight), and does this differ by gender?
# * Is there a relationship between a hero's height and weight and their powerset?
# * What is the distribution of skin colors amongst alien heroes?
#
# Explain your question below this line:
# ____________________________________________________________________________________________________________________________
#
#
#
# Some sample cells have been provided to give you room to work. If you need to create more cells, you can do this easily by:
#
# 1. Highlighting a cell and then pressing `esc` to enter command mode.
# 1. Pressing `b` to add a cell below the currently highlighted cell, or `a` to add one above it.
#
# Be sure to include thoughtful, well-labeled visualizations to back up your analysis!

# %% [markdown]
# ## Summary
#
# In this lab, we demonstrated our mastery of:
# * Using all of our Pandas knowledge to date to clean the dataset and deal with null values
# * Using Queries and aggregations to group the data into interesting subsets as needed
# * Using descriptive statistics and data visualization to find answers to questions we may have about the data

# %% [markdown]
# # Appdendix - Datasets for Demo

# %%
stop

# %%
import pandas as pd

# %%
mice = pd.read_csv('../../datasets/mouse_drinking_data_cleaned.csv')

# %%
mice

# %%
mice.pivot_table(index='Sex',columns=['Group','Mouse_ID'])

# %%
mice_melted = pd.melt(mice,id_vars=['Mouse_ID','Group'],
              value_name='Licks',var_name='Day')
mice_melted
